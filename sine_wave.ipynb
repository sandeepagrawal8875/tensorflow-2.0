# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeepagrawal8875/tensorflow-2.0/blob/main/sine_wave.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.4.1

# %%
import numpy as np
x = np.linspace(1,10*np.pi, 1000)
y = np.sin(x)

# %%
import matplotlib.pyplot as plt
plt.plot(x,y)
plt.show()
